# %%
import pandas as pd
import faiss
import pickle
from sentence_transformers import SentenceTransformer
import os

# %%
BASE_DIR = os.path.abspath('..')
CSV_PATH = os.path.join(BASE_DIR, 'data', 'processed_data', 'web_series', 'web_series.csv')
ARTIFACT_DIR = os.path.join(BASE_DIR, 'artifacts', 'web_series')
os.makedirs(ARTIFACT_DIR, exist_ok=True)

# %%
df = pd.read_csv(CSV_PATH)

# %%
df
# Out:
#                                   title  release year  \
# 0                          Breaking Bad          2008
# 1                       Game of Thrones          2011
# 2                        Rick and Morty          2013
# 3                       Stranger Things          2016
# 4                              The Boys          2019
# ...                                 ...           ...
# 21798                     The Rag Trade          1975
# 21799  Die Real Housewives van Pretoria          2022
# 21800             Abandoned Engineering          2016
# 21801  Diomedes, el Cacique de La Junta          2015
# 21802     MasterChef: The Professionals          2008
#
#                            genre  \
# 0                    Crime,Drama
# 1       Action & Adventure,Drama
# 2               Animation,Comedy
# 3                  Drama,Fantasy
# 4      Action & Adventure,Comedy
# ...                          ...
# 21798                     Comedy
# 21799                 Reality-TV
# 21800                Documentary
# 21801                      Drama
# 21802                 Reality-TV
#
#                                                 synopsis
# 0      When Walter White, a New Mexico chemistry teac...
# 1      Seven noble families fight for control of the ...
# 2      Rick is a mentally-unbalanced but scientifical...
# 3      When a young boy vanishes, a small town uncove...
# 4      A group of vigilantes known informally as “The...
# ...                                                  ...
# 21798                                         Add a Plot
# 21799  Focuses on the personal and professional lives...
# 21800  Structures of steel and iron eerily stand unfi...
# 21801  The life and work of the vallenato musician Di...
# 21802  MasterChef: The Professionals is a BBC televis...
#
# [21803 rows x 4 columns]

# %%
df['tags'] = (
    df['title'].fillna('') + ' ' +
    df['release year'].fillna(0).astype(str) + ' ' +
    df['genre'].fillna('') + ' ' +
    df['synopsis'].fillna('')
)

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(df['tags'].tolist(), show_progress_bar=True, convert_to_numpy=True)
# Out:
# Batches: 100%|███████████████████████████████████████████████████████████████████████| 682/682 [10:25<00:00,  1.09it/s]

# %%
index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(embeddings)

# %%
pickle.dump(df, open(os.path.join(ARTIFACT_DIR, 'data.pkl'), 'wb'))
pickle.dump(model, open(os.path.join(ARTIFACT_DIR, 'sbert_model.pkl'), 'wb'))
faiss.write_index(index, os.path.join(ARTIFACT_DIR, 'faiss_index.index'))

# %%
from rapidfuzz import process
import os
import pickle
import faiss
import numpy as np

def recommend_web_series(title_query, top_k=5):
    ARTIFACT_DIR = os.path.join(BASE_DIR, 'artifacts', 'web_series')

    # Load data, model, and index
    df = pickle.load(open(os.path.join(ARTIFACT_DIR, 'data.pkl'), 'rb'))
    model = pickle.load(open(os.path.join(ARTIFACT_DIR, 'sbert_model.pkl'), 'rb'))
    index = faiss.read_index(os.path.join(ARTIFACT_DIR, 'faiss_index.index'))

    # Step 1: Try exact match
    matches = df[df['title'].str.lower() == title_query.lower()]
    if not matches.empty:
        idx = matches.index[0]
        query = df.loc[idx, 'tags']
        query_vec = model.encode([query], convert_to_numpy=True)
        _, I = index.search(query_vec, top_k + 1)
        return df.iloc[I[0][1:]][['title', 'genre', 'synopsis']]
    
    # Step 2: Fallback to closest match using RapidFuzz
    all_titles = df['title'].fillna('').tolist()
    best_match, score, idx = process.extractOne(title_query, all_titles)
    print(f"⚠️ Title not found. Using closest match: '{best_match}' (Score: {score:.2f})")

    query = df.loc[idx, 'tags']
    query_vec = model.encode([query], convert_to_numpy=True)
    _, I = index.search(query_vec, top_k + 1)
    return df.iloc[I[0][1:]][['title', 'genre', 'synopsis']]

# %%
recommend_web_series('wednesday')
# Out:
#                         title                      genre  \
# 14254  Adult Wednesday Addams                     Comedy
# 15491            Now and Then      Crime, Drama, Mystery
# 19790          More Than This                      Drama
# 13502             High School                     Comedy
# 16228      Krakowskie potwory  Adventure, Drama, Fantasy
#
#                                                 synopsis
# 14254  The chronicles of Wednesday, from "The Addams ...
# 15491  A multi-layered thriller that explores the dif...
# 19790  Explore the real lives of five 17-year-old tee...
# 13502  Based on the autobiographical book High School...
# 16228  A young woman haunted by her past joins a myst...
